# %%
print("Hello Pune!")
# Out:
# Hello Pune!

# %%
print("Hello Pune!")
print("Welcome to Python!")
# Out:
# Hello Pune!
# Welcome to Python!

# %%
num = 56

# %%
print(num)
# Out:
# 56

# %%
num1 = 45.78
print(num1)
# Out:
# 45.78

# %%
num = 53.26
print(num)
# Out:
# 53.26

# %%
name = 'Tushar'
print(name)
# Out:
# Tushar

# %%
print(type(num))
# Out:
# <class 'float'>

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
num
# Out:
# 53.26

# %%
name
# Out:
# 'Tushar'

# %%
num = 264235623756187561416256275675756756237523952935005

# %%
num
# Out:
# 264235623756187561416256275675756756237523952935005

# %%
num = 345 ** 1234

# %%
num
# Out:
# ...

# %%
# Addition program
num1 = 56
num2 = 44
add = num1 + num2   # Addition operator
print("Addition is:", add)
# Out:
# Addition is: 100

# %% [markdown]
# #### Basic Python Program

# %%
num1, num2, num3 = 78, 45, 12

# %%
num2
# Out:
# 45

# %%
val, marks, city = 56, 67.89, 'Pune'

# %%
marks
# Out:
# 67.89

# %%
num1,num2 = 56,44; add = num1 + num2; print("Addition is:", add)
# Out:
# Addition is: 100

# %% [markdown]
# #### Print function

# %%
name = 'Anil'
marks = 67.23

# %%
print('My name is',name,'and marks are',marks)
# Out:
# My name is Anil and marks are 67.23

# %%
print(f'My name is {name} and marks are {marks}')
# Out:
# My name is Anil and marks are 67.23

# %%
print('My name is %s and marks are %.2f' %(name,marks))
# Out:
# My name is Anil and marks are 67.23

# %% [markdown]
# #### Strings

# %%
name = 'Tushar'

# %%
type(name)
# Out:
# str

# %%
print("I like Python Programming!")
# Out:
# I like Python Programming!

# %%
print("I like 'Python' Programming!")
# Out:
# I like 'Python' Programming!

# %%
print('I like "Python" Programming!')
# Out:
# I like "Python" Programming!

# %%
name.upper()
# Out:
# 'TUSHAR'

# %%
name.swapcase()
# Out:
# 'tUSHAR'

# %%
name.count('r')
# Out:
# 1

# %%
name.replace('u','oo')
# Out:
# 'Tooshar'

# %%
help(name.endswith)
# Out:
# Help on built-in function endswith:
#
# endswith(...) method of builtins.str instance
#     S.endswith(suffix[, start[, end]]) -> bool
#
#     Return True if S ends with the specified suffix, False otherwise.
#     With optional start, test S beginning at that position.
#     With optional end, stop comparing S at that position.
#     suffix can also be a tuple of strings to try.

# %% [markdown]
# #### Operators

# %%
# Arithmetic -> + - * / %

# %%
num1 = 45
num2 = 6

# %%
num1 ** num2
# Out:
# 8303765625

# %%
num1 / num2
# Out:
# 7.5

# %%
num1 // num2
# Out:
# 7

# %%
# Relational: <  <=   >   >=   ==   !=

# %%
num1 > num2
# Out:
# True

# %%
# Logical: and or not

# %%
num1 > num2 and num2 < 100
# Out:
# True

# %%
# Member selection
name = 'Tendulkar'

# %%
'kar' in name
# Out:
# True

# %%
'set' in name
# Out:
# False

# %%
'set' not in name
# Out:
# True

# %% [markdown]
# #### Type Conversion

# %%
num1 = 56.78
num2 = 114
add = num1 + num2

# %%
add = int(num1) + num2

# %%
add
# Out:
# 170

# %%
n1 = '123'
n2 = '456'
add = n1 + n2

# %%
add
# Out:
# '123456'

# %%
print(n1, n2)
# Out:
# 123 456

# %%
add = int(n1) + int(n2)
add
# Out:
# 579

# %%
name = 'Pune'
year = 2026

# %%
password = name + str(year)

# %%
password
# Out:
# 'Pune2026'

# %% [markdown]
# #### None

# %%
x = None

# %%
x

# %%
type(x)
# Out:
# NoneType

# %%
print = 78

# %%
print
# Out:
# 78

# %%
print("Hello")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 print("Hello")
#
# TypeError: 'int' object is not callable

# %%
del print

# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# #### User input

# %%
num1 = int(input("Enter first number:"))
num2 = int(input("Enter second number:"))
add = num1 + num2
print("Addition:", add)
# Out:
# Enter first number: 56
# Enter second number: 77
# Addition: 133

# %%
far = float(input('Enter fahrenheit:'))
cent = (far - 32) * 5 / 9
print("Centigrade:", cent)
# Out:
# Enter fahrenheit: -40
# Centigrade: -40.0

# %%
amount = float(input('Enter amount:'))
commission = float(input('Enter commission:'))
final_amount = amount + amount * (commission / 100)
print("Final Amount:", final_amount)
# Out:
# Enter amount: 1000
# Enter commission: 10
# Final Amount: 1100.0
