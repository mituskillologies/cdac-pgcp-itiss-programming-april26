# %% [markdown]
# #### if statement

# %%
num = int(input("Enter a number: "))
if num > 10:
    print("YES")
# Out:
# Enter a number:  23
# YES

# %% [markdown]
# #### if - else Statement

# %%
num = int(input("Enter a number: "))
if num < 0:
    print("Negative!")
    print("OK")
else:
    print("Positive!")
    print("Done")

print("Program Ended.")
# Out:
# Enter a number:  45
# Positive!
# Done
# Program Ended.

# %%
num = int(input("Enter a number: "))
if num < 0:         # Compulsory, condition, non-repeatable
    print("Negative!")
elif num == 0:      # Optional, condition, repeatable
    print("ZERO!")
else:               # Optional, no-condition, non-repeatable
    print("Positive!")
# Out:
# Enter a number:  0
# ZERO!

# %%
num = int(input("Enter a number: "))
if num == 0:        
    print("ZERO!")
elif num % 2 == 0:      
    print("Even!")
else:               
    print("Odd!")
# Out:
# Enter a number:  7
# Odd!

# %%
purchase_cost = float(input("Enter purchase cost:"))
selling_cost = float(input("Enter selling cost:"))
if purchase_cost < selling_cost:
    print("Profit:", selling_cost - purchase_cost)
else:
    print("Loss:", purchase_cost - selling_cost)
# Out:
# Enter purchase cost: 5000
# Enter selling cost: 6700
# Profit: 1700.0
